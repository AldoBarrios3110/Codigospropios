# %% [markdown]
# <a href="https://colab.research.google.com/github/AldoBarrios3110/Codigospropios/blob/main/jacobi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tkinter import *
def jacobi():
 iter=10
 x0=0
 y0=0
 z0=0
 x1 = int(X1.get())
 x2 = int(X2.get())
 x3 = int(X3.get())
 d = int(D.get())
 y1 = int(Y1.get())
 y2 = int(Y2.get())
 y3 = int(Y3.get())
 d2 = int(D2.get())
 z1 = int(Z1.get())
 z2 = int(Z2.get())
 z3 = int(Z3.get())
 d3 = int(D3.get())

 if x2 > x1 and x1 > x3:
    yaux=0
    Xaux=0
    zaux=0
    daux=0
    Xaux=x1
    yaux=y1
    zaux=z1
    daux=d
    x1=x2
    y1=y2
    z1=z2
    d=d2
    x2=Xaux
    y2=yaux
    z2=zaux
    d2=daux
    if y3 > y2:
        yaux = 0
        Xaux = 0
        zaux = 0
        daux=0
        Xaux = x2
        yaux = y2
        zaux = z2
        daux = d2
        x2 = x3
        y2 = y3
        z2 = z3
        d2 = d3
        x3 = Xaux
        y3 = yaux
        z3 = zaux
        d3 = daux

 for i in range(iter-1):
     X=((d)+(-1*y1*y0)+(-1*z1*z0))/(x1)
     Y=((d2)+(-1*x2*x0)+(-1*z2*z0))/(y2)
     Z=((d3)+(-1*x3*x0)+(-1*y3*y0))/(z3)
     XA=x0
     YA=y0
     ZA=z0
     print(X)
     x0=round(X,4)
     y0=round(Y,4)
     z0=round(Z,4)
     print("Iteracion",i+1, ", valor X: ", x0,", valor Y: ",y0,", valor z: ",z0 )
     if i==iter-2:
      print("Error en las X", abs((x0 - XA) / x0))
      print("Error en las Y", abs((x0 - XA) / x0))
      print("Error en las Z", abs((x0 - XA) / x0))

frame = Tk()
frame.title("Menú principal")
frameI=Frame()
frameI.pack()
frameI.config(width="700", height="600")
frameI.config(bg="grey")
Label(frameI, text="Introduce los datos para Jacobi", bg="grey", font=(14)).place(x=260,y=20)
Label(frameI, text="El resultado final es el siguiente:  ", bg="grey", font=(14)).place(x=260,y=380)
boton1=Button(frameI,text="Calcular", bg="grey", font=(14), command=jacobi).place(x=260,y=410)
X1=StringVar()
Y1=StringVar()
Z1=StringVar()
D=StringVar()
Label(frameI, text="X de ecuación 1", bg="grey", font=(14)).place(x=55,y=80)
Ex1 = Entry(frameI, bg="grey", textvariable =X1).place(x=55,y=110)
Label(frameI, text="Y de ecuación 1", bg="grey", font=(14)).place(x=200,y=80)
Ey1 = Entry(frameI, bg="grey",textvariable =Y1).place(x=200,y=110)
Label(frameI, text="Z de ecuación 1", bg="grey", font=(14)).place(x=350,y=80)
Ez1 = Entry(frameI, bg="grey",textvariable=Z1).place(x=350,y=110)
Label(frameI, text="Igualdad 1", bg="grey", font=(14)).place(x=525,y=80)
Ed= Entry(frameI, bg="grey",textvariable=D).place(x=505,y=110)
X2=StringVar()
Y2=StringVar()
Z2=StringVar()
D2=StringVar()
Label(frameI, text="X de ecuación 2", bg="grey", font=(14)).place(x=55,y=180)
Ex2 = Entry(frameI, bg="grey",textvariable=X2).place(x=55,y=210)
Label(frameI, text="Y de ecuación 2", bg="grey", font=(14)).place(x=200,y=180)
Ey2 = Entry(frameI, bg="grey",textvariable=Y2).place(x=200,y=210)
Label(frameI, text="Z de ecuación 2", bg="grey", font=(14)).place(x=350,y=180)
Ez2 = Entry(frameI, bg="grey",textvariable=Z2).place(x=350,y=210)
Label(frameI, text="Igualdad 2", bg="grey", font=(14)).place(x=525,y=180)
Ed2= Entry(frameI, bg="grey",textvariable=D2).place(x=505,y=210)
X3=StringVar()
Y3=StringVar()
Z3=StringVar()
D3=StringVar()
Label(frameI, text="X de ecuación 3", bg="grey", font=(14)).place(x=55,y=280)
Ex3 = Entry(frameI, bg="grey",textvariable=X3).place(x=55,y=310)
Label(frameI, text="Y de ecuación 3", bg="grey", font=(14)).place(x=200,y=280)
Ey3 = Entry(frameI, bg="grey",textvariable=Y3).place(x=200,y=310)
Label(frameI, text="Z de ecuación 3", bg="grey", font=(14)).place(x=350,y=280)
Ez3 = Entry(frameI, bg="grey",textvariable=Z3).place(x=350,y=310)
Label(frameI, text="Igualdad 3", bg="grey", font=(14)).place(x=525,y=280)
Ed3= Entry(frameI, bg="grey",textvariable=D3).place(x=505,y=310)
frame.mainloop()
